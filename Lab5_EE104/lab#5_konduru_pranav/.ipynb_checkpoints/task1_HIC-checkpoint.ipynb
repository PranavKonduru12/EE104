# %%
import math as m
import matplotlib.pyplot as plt
import numpy as np
import scipy.integrate as integ

# %% [markdown]
# Plot a(t):
# $$
#   a(t)=\frac{22000}{(t-74)^2+500}
# $$

# %%
# Plot a(t)
def a1(x):
    x = [x/2 for x in range(300)]
    y = [22000 / ((v - 74)**2 + 500) for v in x]
    return y

# %%
plt.plot(x,a1(x))
